# %% [markdown]
# Train the model

# %%
from keras_transformer import get_model, decode

import tensorflow as tf
import numpy as np
import joblib

# %%
#Load the data
SAVE_PATH = "../../../../../../data/processed/translator-data/es-en/dataset.npz"

npz = np.load(SAVE_PATH,  allow_pickle=True)
enc_inputs, dec_inputs, dec_outputs = npz['enc_inputs'], npz['dec_inputs'], npz['dec_outputs']

# %%
#Load the tokenizers
TOKENIZER_EN_PATH = '../../../../../../exports/translator/tokenizers/english/tokenizer.pkl'
TOKENIZER_ES_PATH = '../../../../../../exports/translator/tokenizers/spanish/tokenizer.pkl'

tokenizer_en = joblib.load(TOKENIZER_EN_PATH)
tokenizer_es = joblib.load(TOKENIZER_ES_PATH)

# %%
#Train the model

# Hyperparameters
D_MODEL = 128 # 512
NB_LAYERS = 4 # 6
FFN_UNITS = 512 # 2048
NB_PROJ = 8
DROPOUT_RATE = 0.05
VOCAB_SIZE_EN = tokenizer_en.vocab_size + 2
VOCAB_SIZE_ES = tokenizer_es.vocab_size + 2

transformer = get_model(
    token_num = max(VOCAB_SIZE_ES, VOCAB_SIZE_EN),
    embed_dim = 32,
    encoder_num = NB_LAYERS,
    decoder_num = NB_LAYERS,
    head_num = NB_PROJ,
    hidden_dim = FFN_UNITS,
    dropout_rate = DROPOUT_RATE,
    use_same_embed = False,
)
transformer.compile('adam', 'sparse_categorical_crossentropy')
transformer.summary()
# Out:
# /Users/josecamacho/Desktop/Projects/jotaNLP/ml/venv/lib/python3.11/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Encoder-Input (InputLayer)  [(None, None)]               0         []
#
#  Encoder-Token-Embedding (E  [(None, None, 32),           268832    ['Encoder-Input[0][0]']
#  mbeddingRet)                 (8401, 32)]
#
#  Encoder-Embedding (TrigPos  (None, None, 32)             0         ['Encoder-Token-Embedding[0][0
#  Embedding)                                                         ]']
#
#  Encoder-1-MultiHeadSelfAtt  (None, None, 32)             4224      ['Encoder-Embedding[0][0]']
#  ention (MultiHeadAttention
#  )
#
#  Encoder-1-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-1-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-1-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-Embedding[0][0]',
#  ention-Add (Add)                                                    'Encoder-1-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-1-MultiHeadSelfAtt  (None, None, 32)             64        ['Encoder-1-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-1-FeedForward (Fee  (None, None, 32)             33312     ['Encoder-1-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-1-FeedForward-Drop  (None, None, 32)             0         ['Encoder-1-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-1-FeedForward-Add   (None, None, 32)             0         ['Encoder-1-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-1-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-1-FeedForward-Norm  (None, None, 32)             64        ['Encoder-1-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-2-MultiHeadSelfAtt  (None, None, 32)             4224      ['Encoder-1-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-2-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-2-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-2-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-1-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-2-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-2-MultiHeadSelfAtt  (None, None, 32)             64        ['Encoder-2-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-2-FeedForward (Fee  (None, None, 32)             33312     ['Encoder-2-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-2-FeedForward-Drop  (None, None, 32)             0         ['Encoder-2-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-2-FeedForward-Add   (None, None, 32)             0         ['Encoder-2-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-2-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-2-FeedForward-Norm  (None, None, 32)             64        ['Encoder-2-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-3-MultiHeadSelfAtt  (None, None, 32)             4224      ['Encoder-2-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-3-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-3-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-3-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-2-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-3-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-3-MultiHeadSelfAtt  (None, None, 32)             64        ['Encoder-3-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-3-FeedForward (Fee  (None, None, 32)             33312     ['Encoder-3-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-3-FeedForward-Drop  (None, None, 32)             0         ['Encoder-3-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-3-FeedForward-Add   (None, None, 32)             0         ['Encoder-3-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-3-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-3-FeedForward-Norm  (None, None, 32)             64        ['Encoder-3-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-4-MultiHeadSelfAtt  (None, None, 32)             4224      ['Encoder-3-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Decoder-Input (InputLayer)  [(None, None)]               0         []
#
#  Encoder-4-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-4-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Decoder-Token-Embedding (E  [(None, None, 32),           268832    ['Decoder-Input[0][0]']
#  mbeddingRet)                 (8401, 32)]
#
#  Encoder-4-MultiHeadSelfAtt  (None, None, 32)             0         ['Encoder-3-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-4-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Decoder-Embedding (TrigPos  (None, None, 32)             0         ['Decoder-Token-Embedding[0][0
#  Embedding)                                                         ]']
#
#  Encoder-4-MultiHeadSelfAtt  (None, None, 32)             64        ['Encoder-4-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Decoder-1-MultiHeadSelfAtt  (None, None, 32)             4224      ['Decoder-Embedding[0][0]']
#  ention (MultiHeadAttention
#  )
#
#  Encoder-4-FeedForward (Fee  (None, None, 32)             33312     ['Encoder-4-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Decoder-1-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-1-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-4-FeedForward-Drop  (None, None, 32)             0         ['Encoder-4-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Decoder-1-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-Embedding[0][0]',
#  ention-Add (Add)                                                    'Decoder-1-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-4-FeedForward-Add   (None, None, 32)             0         ['Encoder-4-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-4-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Decoder-1-MultiHeadSelfAtt  (None, None, 32)             64        ['Decoder-1-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-4-FeedForward-Norm  (None, None, 32)             64        ['Encoder-4-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Decoder-1-MultiHeadQueryAt  (None, None, 32)             4224      ['Decoder-1-MultiHeadSelfAtten
#  tention (MultiHeadAttentio                                         tion-Norm[0][0]',
#  n)                                                                  'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]',
#                                                                      'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]']
#
#  Decoder-1-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-1-MultiHeadQueryAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Decoder-1-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-1-MultiHeadSelfAtten
#  tention-Add (Add)                                                  tion-Norm[0][0]',
#                                                                      'Decoder-1-MultiHeadQueryAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Decoder-1-MultiHeadQueryAt  (None, None, 32)             64        ['Decoder-1-MultiHeadQueryAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Decoder-1-FeedForward (Fee  (None, None, 32)             33312     ['Decoder-1-MultiHeadQueryAtte
#  dForward)                                                          ntion-Norm[0][0]']
#
#  Decoder-1-FeedForward-Drop  (None, None, 32)             0         ['Decoder-1-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Decoder-1-FeedForward-Add   (None, None, 32)             0         ['Decoder-1-MultiHeadQueryAtte
#  (Add)                                                              ntion-Norm[0][0]',
#                                                                      'Decoder-1-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Decoder-1-FeedForward-Norm  (None, None, 32)             64        ['Decoder-1-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Decoder-2-MultiHeadSelfAtt  (None, None, 32)             4224      ['Decoder-1-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Decoder-2-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-2-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Decoder-2-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-1-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Decoder-2-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Decoder-2-MultiHeadSelfAtt  (None, None, 32)             64        ['Decoder-2-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Decoder-2-MultiHeadQueryAt  (None, None, 32)             4224      ['Decoder-2-MultiHeadSelfAtten
#  tention (MultiHeadAttentio                                         tion-Norm[0][0]',
#  n)                                                                  'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]',
#                                                                      'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]']
#
#  Decoder-2-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-2-MultiHeadQueryAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Decoder-2-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-2-MultiHeadSelfAtten
#  tention-Add (Add)                                                  tion-Norm[0][0]',
#                                                                      'Decoder-2-MultiHeadQueryAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Decoder-2-MultiHeadQueryAt  (None, None, 32)             64        ['Decoder-2-MultiHeadQueryAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Decoder-2-FeedForward (Fee  (None, None, 32)             33312     ['Decoder-2-MultiHeadQueryAtte
#  dForward)                                                          ntion-Norm[0][0]']
#
#  Decoder-2-FeedForward-Drop  (None, None, 32)             0         ['Decoder-2-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Decoder-2-FeedForward-Add   (None, None, 32)             0         ['Decoder-2-MultiHeadQueryAtte
#  (Add)                                                              ntion-Norm[0][0]',
#                                                                      'Decoder-2-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Decoder-2-FeedForward-Norm  (None, None, 32)             64        ['Decoder-2-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Decoder-3-MultiHeadSelfAtt  (None, None, 32)             4224      ['Decoder-2-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Decoder-3-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-3-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Decoder-3-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-2-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Decoder-3-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Decoder-3-MultiHeadSelfAtt  (None, None, 32)             64        ['Decoder-3-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Decoder-3-MultiHeadQueryAt  (None, None, 32)             4224      ['Decoder-3-MultiHeadSelfAtten
#  tention (MultiHeadAttentio                                         tion-Norm[0][0]',
#  n)                                                                  'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]',
#                                                                      'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]']
#
#  Decoder-3-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-3-MultiHeadQueryAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Decoder-3-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-3-MultiHeadSelfAtten
#  tention-Add (Add)                                                  tion-Norm[0][0]',
#                                                                      'Decoder-3-MultiHeadQueryAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Decoder-3-MultiHeadQueryAt  (None, None, 32)             64        ['Decoder-3-MultiHeadQueryAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Decoder-3-FeedForward (Fee  (None, None, 32)             33312     ['Decoder-3-MultiHeadQueryAtte
#  dForward)                                                          ntion-Norm[0][0]']
#
#  Decoder-3-FeedForward-Drop  (None, None, 32)             0         ['Decoder-3-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Decoder-3-FeedForward-Add   (None, None, 32)             0         ['Decoder-3-MultiHeadQueryAtte
#  (Add)                                                              ntion-Norm[0][0]',
#                                                                      'Decoder-3-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Decoder-3-FeedForward-Norm  (None, None, 32)             64        ['Decoder-3-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Decoder-4-MultiHeadSelfAtt  (None, None, 32)             4224      ['Decoder-3-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Decoder-4-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-4-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Decoder-4-MultiHeadSelfAtt  (None, None, 32)             0         ['Decoder-3-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Decoder-4-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Decoder-4-MultiHeadSelfAtt  (None, None, 32)             64        ['Decoder-4-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Decoder-4-MultiHeadQueryAt  (None, None, 32)             4224      ['Decoder-4-MultiHeadSelfAtten
#  tention (MultiHeadAttentio                                         tion-Norm[0][0]',
#  n)                                                                  'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]',
#                                                                      'Encoder-4-FeedForward-Norm[0
#                                                                     ][0]']
#
#  Decoder-4-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-4-MultiHeadQueryAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Decoder-4-MultiHeadQueryAt  (None, None, 32)             0         ['Decoder-4-MultiHeadSelfAtten
#  tention-Add (Add)                                                  tion-Norm[0][0]',
#                                                                      'Decoder-4-MultiHeadQueryAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Decoder-4-MultiHeadQueryAt  (None, None, 32)             64        ['Decoder-4-MultiHeadQueryAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Decoder-4-FeedForward (Fee  (None, None, 32)             33312     ['Decoder-4-MultiHeadQueryAtte
#  dForward)                                                          ntion-Norm[0][0]']
#
#  Decoder-4-FeedForward-Drop  (None, None, 32)             0         ['Decoder-4-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Decoder-4-FeedForward-Add   (None, None, 32)             0         ['Decoder-4-MultiHeadQueryAtte
#  (Add)                                                              ntion-Norm[0][0]',
#                                                                      'Decoder-4-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Decoder-4-FeedForward-Norm  (None, None, 32)             64        ['Decoder-4-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Decoder-Output (EmbeddingS  (None, None, 8401)           8401      ['Decoder-4-FeedForward-Norm[0
#  im)                                                                ][0]',
#                                                                      'Decoder-Token-Embedding[0][1
#                                                                     ]']
#
# ==================================================================================================
# Total params: 864529 (3.30 MB)
# Trainable params: 864529 (3.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint_path = "../../../../../../checkpoints/translator/es-en/transformer"

ckpt = tf.train.Checkpoint(transformer=transformer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=2)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print("Last checkpoint restored!!")

# %%
# Training
x = [enc_inputs, dec_inputs]

transformer.fit(x, dec_outputs, epochs=15, batch_size=32)
ckpt_manager.save()
